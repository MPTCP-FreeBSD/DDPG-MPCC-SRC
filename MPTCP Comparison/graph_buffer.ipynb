# %%
# import pandas as pd

# df=pd.read_csv("results-trialc.txt", names=["experiment_number","congestion_control","bottleneck_buffer","thrpt_t1","thrpt_t2","thrpt_unit","latency"])

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

df=pd.read_csv("./bandwidthdata/results-trialc.txt", names=["experiment_number","congestion_control","bottleneck_buffer","thrpt_mp","reno_name","thrpt_sp","latency_name","latency"])

df['bottleneck_buffer']=df['bottleneck_buffer']/1024

# df['bottleneck_buffer']=pd.Series(np.log10(df['bottleneck_buffer'].to_numpy()))

# %%
df
# Out:
#      experiment_number congestion_control  bottleneck_buffer  thrpt_mp  \
# 0                    1               reno              375.0      87.7
# 1                    1                pcc              375.0      91.9
# 2                    1              balia              375.0      77.7
# 3                    1                bbr              375.0     114.0
# 4                    1                lia              375.0      71.2
# ..                 ...                ...                ...       ...
# 139                  3                bbr             1000.0      60.8
# 140                  3                lia             1000.0      73.6
# 141                  3               olia             1000.0     109.0
# 142                  3             wvegas             1000.0      51.1
# 143                  3           pcc_loss             1000.0     119.0
#
#     reno_name  thrpt_sp latency_name  latency
# 0        reno     104.0      latency  48.2542
# ...

# %%
plt.rcParams.update({'figure.figsize':(8,6), 'figure.dpi':100, 'font.size':16})

# %%
train_df=df.copy()
train_df.set_index(df['bottleneck_buffer'])

tcp_group=train_df.groupby(df['congestion_control'])





tcp_list=[]
tcp_list_pd=[]


for group_key, group_value in tcp_group:
    group = tcp_group.get_group(group_key)
    group=group.set_index(group['bottleneck_buffer'])
    group=group.groupby(group.index).mean()
    group=group[['latency']]

    plt.plot(group.index,group['latency'],label=group_key)
    

    # if(group_key=="balia"):
    # group.plot(color="red")

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)
            


    tcp_list.append(group_key)
    tcp_list_pd.append(group)


    # group.plot(color="red")
    # from matplotlib.pyplot import figure

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)

title="latency vs bottleneck in network a"
plt.title("latency vs bottleneck in network a")
plt.legend()
plt.savefig("./iperf3_tests/"+title+"-"+"Graphs.png", dpi=100,bbox_inches='tight')
plt.show()

# %%
train_df=df.copy()
train_df.set_index(df['bottleneck_buffer'])

tcp_group=train_df.groupby(df['congestion_control'])

train_df_temp=train_df.loc[train_df['congestion_control']=="reno"]

train_df

import matplotlib.pyplot as plt
import numpy as np

from matplotlib.pyplot import figure


tcp_list=[]
tcp_list_pd=[]


for group_key, group_value in tcp_group:
    group = tcp_group.get_group(group_key)
    group=group.set_index(group['bottleneck_buffer'])
    group=group.groupby(group.index).mean()
    if group_key=="reno":
        group['thrpt_mp']=group[['thrpt_sp']]
        # print(group)
    group=group[['thrpt_mp']]

    plt.plot(group.index,group['thrpt_mp'],label=group_key)

    # if(group_key=="balia"):
    # group.plot(color="red")

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)
            


    tcp_list.append(group_key)
    tcp_list_pd.append(group)


    # group.plot(color="red")
    # from matplotlib.pyplot import figure

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)


title="Goodput vs bottleneck in network a"
plt.title("Goodput vs bottleneck in network a")
plt.legend()
plt.savefig("./iperf3_tests/"+title+"-"+"Graphs.png", dpi=100,facecolor='white', transparent=False,bbox_inches='tight')
plt.show()

# %%
# import pandas as pd

# df=pd.read_csv("results-trialc.txt", names=["experiment_number","congestion_control","bottleneck_buffer","thrpt_t1","thrpt_t2","thrpt_unit","latency"])

import pandas as pd

import numpy as np

df=pd.read_csv("./bandwidthdata/results-triald.txt", names=["experiment_number","congestion_control","bottleneck_buffer","thrpt_mp","reno_name","thrpt_sp1","thrpt_sp2","unit","latency_name","latency"])

df['bottleneck_buffer']=df['bottleneck_buffer']/1024

# df['bottleneck_buffer']=pd.Series(np.log10(df['bottleneck_buffer'].to_numpy()))

# %%
df
# Out:
#      experiment_number congestion_control  bottleneck_buffer  thrpt_mp  \
# 0                    1               reno              375.0      85.2
# 1                    1                pcc              375.0      71.4
# 2                    1              balia              375.0      74.7
# 3                    1                bbr              375.0     104.0
# 4                    1                lia              375.0      72.9
# ..                 ...                ...                ...       ...
# 139                  3                bbr             1000.0      58.7
# 140                  3                lia             1000.0      77.3
# 141                  3               olia             1000.0      55.0
# 142                  3             wvegas             1000.0      50.3
# 143                  3           pcc_loss             1000.0      62.7
#
#     reno_name  thrpt_sp1  thrpt_sp2       unit latency_name  latency
# ...

# %%
train_df=df.copy()
train_df.set_index(df['bottleneck_buffer'])

tcp_group=train_df.groupby(df['congestion_control'])

import matplotlib.pyplot as plt
import numpy as np

from matplotlib.pyplot import figure


tcp_list=[]
tcp_list_pd=[]


for group_key, group_value in tcp_group:
    group = tcp_group.get_group(group_key)
    group=group.set_index(group['bottleneck_buffer'])
    group=group.groupby(group.index).mean()
    group=group[['latency']]

    plt.plot(group.index,group['latency'],label=group_key)
    

    # if(group_key=="balia"):
    # group.plot(color="red")

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)
            


    tcp_list.append(group_key)
    tcp_list_pd.append(group)


    # group.plot(color="red")
    # from matplotlib.pyplot import figure

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)

title="latency vs bottleneck in network b"
plt.title("latency vs bottleneck in network b")
plt.legend()

plt.savefig("./iperf3_tests/"+title+"-"+"Graphs.png", dpi=100,facecolor='white', transparent=False,bbox_inches='tight')
plt.show()

# %%
train_df=df.copy()
train_df.set_index(df['bottleneck_buffer'])

tcp_group=train_df.groupby(df['congestion_control'])

train_df_temp=train_df.loc[train_df['congestion_control']=="reno"]

train_df

import matplotlib.pyplot as plt
import numpy as np

from matplotlib.pyplot import figure


tcp_list=[]
tcp_list_pd=[]


for group_key, group_value in tcp_group:
    group = tcp_group.get_group(group_key)
    group=group.set_index(group['bottleneck_buffer'])
    group=group.groupby(group.index).mean()
    if group_key=="reno":
        group['thrpt_mp']=group['thrpt_sp1']+group['thrpt_sp2']
        group['thrpt_mp']=group["thrpt_mp"]/2
        # print(group)
    group=group[['thrpt_mp']]

    plt.plot(group.index,group['thrpt_mp'],label=group_key)

    # if(group_key=="balia"):
    # group.plot(color="red")

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)
            


    tcp_list.append(group_key)
    tcp_list_pd.append(group)


    # group.plot(color="red")
    # from matplotlib.pyplot import figure

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)

title="Goodput vs bottleneck in network b"
plt.title("Goodput vs bottleneck in network b")
plt.legend()
plt.savefig("./iperf3_tests/"+title+"-"+"Graphs.png", dpi=100,facecolor='white', transparent=False,bbox_inches='tight')
plt.show()

# %%
# import pandas as pd

# df=pd.read_csv("results-trialc.txt", names=["experiment_number","congestion_control","bottleneck_buffer","thrpt_t1","thrpt_t2","thrpt_unit","latency"])

import pandas as pd

import numpy as np

df=pd.read_csv("./bandwidthdata/results-triale.txt", names=["experiment_number","congestion_control","bottleneck_buffer","thrpt_mp1","thrpt_mp2","unit","latency_name","latency"])

df['bottleneck_buffer']=df['bottleneck_buffer']/1024

# df['bottleneck_buffer']=pd.Series(np.log10(df['bottleneck_buffer'].to_numpy()))

# %%
df
# Out:
#      experiment_number congestion_control  bottleneck_buffer  thrpt_mp1  \
# 0                    1               reno              375.0      104.0
# 1                    1                pcc              375.0       68.1
# 2                    1              balia              375.0      109.0
# 3                    1                bbr              375.0      109.0
# 4                    1                lia              375.0      120.0
# ..                 ...                ...                ...        ...
# 139                  3                bbr             1000.0      112.0
# 140                  3                lia             1000.0       88.1
# 141                  3               olia             1000.0       60.9
# 142                  3             wvegas             1000.0       46.9
# 143                  3           pcc_loss             1000.0       80.8
#
#      thrpt_mp2       unit latency_name  latency
# 0         87.8  Mbits/sec      latency  49.2382
# ...

# %%
train_df=df.copy()
train_df.set_index(df['bottleneck_buffer'])

tcp_group=train_df.groupby(df['congestion_control'])

import matplotlib.pyplot as plt
import numpy as np

from matplotlib.pyplot import figure


tcp_list=[]
tcp_list_pd=[]


for group_key, group_value in tcp_group:
    group = tcp_group.get_group(group_key)
    group=group.set_index(group['bottleneck_buffer'])
    group=group.groupby(group.index).mean()
    group=group[['latency']]

    plt.plot(group.index,group['latency'],label=group_key)
    

    # if(group_key=="balia"):
    # group.plot(color="red")

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)
            


    tcp_list.append(group_key)
    tcp_list_pd.append(group)


    # group.plot(color="red")
    # from matplotlib.pyplot import figure

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)

title="latency vs bottleneck in network c"
plt.title("latency vs bottleneck in network c")
plt.legend()
plt.savefig("./iperf3_tests/"+title+"-"+"Graphs.png", dpi=100,facecolor='white', transparent=False,bbox_inches='tight')
plt.show()




train_df=df.copy()
train_df.set_index(df['bottleneck_buffer'])

tcp_group=train_df.groupby(df['congestion_control'])

train_df_temp=train_df.loc[train_df['congestion_control']=="reno"]

train_df

import matplotlib.pyplot as plt
import numpy as np

from matplotlib.pyplot import figure


tcp_list=[]
tcp_list_pd=[]


for group_key, group_value in tcp_group:
    group = tcp_group.get_group(group_key)
    group=group.set_index(group['bottleneck_buffer'])
    group=group.groupby(group.index).mean()
    
    group['thrpt_mp']=group['thrpt_mp1']
        # print(group)
    group=group[['thrpt_mp']]

    plt.plot(group.index,group['thrpt_mp'],label=group_key)

    # if(group_key=="balia"):
    # group.plot(color="red")

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)
            


    tcp_list.append(group_key)
    tcp_list_pd.append(group)


    # group.plot(color="red")
    # from matplotlib.pyplot import figure

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)

title="Goodput vs bottleneck in network c"
plt.title("Goodput vs bottleneck in network c")
plt.legend()
plt.savefig("./iperf3_tests/"+title+"-"+"Graphs.png", dpi=100,facecolor='white', transparent=False,bbox_inches='tight')
plt.show()
