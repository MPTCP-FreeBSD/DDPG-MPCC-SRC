# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure


df=pd.read_csv("./losspercentagedata/results-trialc.txt", names=["experiment_number","congestion_control","loss_percentage","thrpt_mp","reno_name","thrpt_sp","latency_name","latency"])

# %%
df
# Out:
#      experiment_number congestion_control  loss_percentage  thrpt_mp  \
# 0                    1               reno            0.001     20.80
# 1                    1                pcc            0.001     42.20
# 2                    1              balia            0.001     11.90
# 3                    1                bbr            0.001      7.63
# 4                    1                lia            0.001     11.80
# ..                 ...                ...              ...       ...
# 171                  2                bbr           10.000     14.50
# 172                  2                lia           10.000      0.34
# 173                  2               olia           10.000      0.51
# 174                  2             wvegas           10.000      0.64
# 175                  2           pcc_loss           10.000      2.92
#
#     reno_name  thrpt_sp latency_name  latency
# 0        reno     20.90      latency  60.5934
# 1        reno     11.70      latency  62.3602
# 2        reno     20.90      latency  60.7578
# 3        reno     15.60      latency  60.4899
# 4        reno     20.90      latency  60.7511
# ..        ...       ...          ...      ...
# 171      reno      0.59      latency  64.9067
# 172      reno      0.79      latency  86.6506
# 173      reno      0.78      latency  66.2569
# 174      reno      0.77      latency  71.2518
# 175      reno      0.56      latency  62.0331
#
# [176 rows x 8 columns]

# %%
plt.rcParams.update({'figure.figsize':(8,6), 'figure.dpi':100, 'font.size':16})

# %%
train_df=df.copy()
train_df.set_index(df['loss_percentage'])

tcp_group=train_df.groupby(df['congestion_control'])



tcp_list=[]
tcp_list_pd=[]


for group_key, group_value in tcp_group:
    group = tcp_group.get_group(group_key)
    group=group.set_index(group['loss_percentage'])
    group=group.groupby(group.index).mean()
    group=group[['latency']]

    plt.plot(group.index,group['latency'],label=group_key)
    

    # if(group_key=="balia"):
    # group.plot(color="red")

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)
            


    tcp_list.append(group_key)
    tcp_list_pd.append(group)


    # group.plot(color="red")
    # from matplotlib.pyplot import figure

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)

title="latency vs loss percentage in network a"
plt.title("latency vs loss percentage in network a")
plt.legend()
plt.savefig("./iperf3_tests/"+title+"-"+"Graphs.png", dpi=100,facecolor='white', transparent=False,bbox_inches='tight')
plt.show()

# %%
train_df=df.copy()
train_df.set_index(df['loss_percentage'])

tcp_group=train_df.groupby(df['congestion_control'])

train_df_temp=train_df.loc[train_df['congestion_control']=="reno"]

train_df

import matplotlib.pyplot as plt
import numpy as np

from matplotlib.pyplot import figure


tcp_list=[]
tcp_list_pd=[]


for group_key, group_value in tcp_group:
    group = tcp_group.get_group(group_key)
    group=group.set_index(group['loss_percentage'])
    group=group.groupby(group.index).mean()
    if group_key=="reno":
        group['thrpt_mp']=group[['thrpt_sp']]
        # print(group)
    group=group[['thrpt_mp']]

    plt.plot(group.index,group['thrpt_mp'],label=group_key)

    # if(group_key=="balia"):
    # group.plot(color="red")

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)
            


    tcp_list.append(group_key)
    tcp_list_pd.append(group)


    # group.plot(color="red")
    # from matplotlib.pyplot import figure

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)


title="Goodput vs loss percentage in network a"
plt.title("Goodput vs loss percentage in network a")
plt.legend()
plt.savefig("./iperf3_tests/"+title+"-"+"Graphs.png", dpi=100,facecolor='white', transparent=False,bbox_inches='tight')
plt.show()

# %%
import pandas as pd

import numpy as np

df=pd.read_csv("./losspercentagedata/results-triald.txt", names=["experiment_number","congestion_control","loss_percentage","thrpt_mp","reno_name","thrpt_sp1","thrpt_sp2","unit","latency_name","latency"])

# %%
df
# Out:
#      experiment_number congestion_control  loss_percentage  thrpt_mp  \
# 0                    1               reno            0.001     33.00
# 1                    1                pcc            0.001     50.50
# 2                    1              balia            0.001     29.80
# 3                    1                bbr            0.001      7.88
# 4                    1                lia            0.001     30.00
# ..                 ...                ...              ...       ...
# 171                  2                bbr           10.000     62.30
# 172                  2                lia           10.000      0.39
# 173                  2               olia           10.000      0.44
# 174                  2             wvegas           10.000      0.51
# 175                  2           pcc_loss           10.000      2.66
#
#     reno_name  thrpt_sp1  thrpt_sp2       unit latency_name   latency
# 0        reno      32.80      29.30  Mbits/sec      latency   63.3610
# 1        reno      18.80      18.60  Mbits/sec      latency   70.3015
# 2        reno      26.90      37.30  Mbits/sec      latency   65.2133
# 3        reno      39.80      39.50  Mbits/sec      latency   62.4925
# 4        reno      37.50      24.90  Mbits/sec      latency   65.0880
# ..        ...        ...        ...        ...          ...       ...
# 171      reno       0.51       0.39  Mbits/sec      latency  127.4360
# 172      reno       0.61       0.34  Mbits/sec      latency  104.8130
# 173      reno       0.54       0.69  Mbits/sec      latency   69.7340
# 174      reno       0.72       0.82  Mbits/sec      latency   68.1557
# 175      reno       0.49       0.66  Mbits/sec      latency   72.1859
#
# [176 rows x 10 columns]

# %%
train_df=df.copy()
train_df.set_index(df['loss_percentage'])

tcp_group=train_df.groupby(df['congestion_control'])

import matplotlib.pyplot as plt
import numpy as np

from matplotlib.pyplot import figure


tcp_list=[]
tcp_list_pd=[]


for group_key, group_value in tcp_group:
    group = tcp_group.get_group(group_key)
    group=group.set_index(group['loss_percentage'])
    group=group.groupby(group.index).mean()
    group=group[['latency']]

    plt.plot(group.index,group['latency'],label=group_key)
    

    # if(group_key=="balia"):
    # group.plot(color="red")

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)
            


    tcp_list.append(group_key)
    tcp_list_pd.append(group)


    # group.plot(color="red")
    # from matplotlib.pyplot import figure

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)

title="latency vs loss percentage in network b"
plt.title("latency vs loss percentage in network b")
plt.legend()
plt.savefig("./iperf3_tests/"+title+"-"+"Graphs.png", dpi=100,facecolor='white', transparent=False,bbox_inches='tight')
plt.show()

# %%
train_df=df.copy()
train_df.set_index(df['loss_percentage'])

tcp_group=train_df.groupby(df['congestion_control'])

train_df_temp=train_df.loc[train_df['congestion_control']=="reno"]

train_df

import matplotlib.pyplot as plt
import numpy as np

from matplotlib.pyplot import figure


tcp_list=[]
tcp_list_pd=[]


for group_key, group_value in tcp_group:
    group = tcp_group.get_group(group_key)
    group=group.set_index(group['loss_percentage'])
    group=group.groupby(group.index).mean()
    if group_key=="reno":
        group['thrpt_mp']=group['thrpt_sp1']+group['thrpt_sp2']
        group['thrpt_mp']=group["thrpt_mp"]/2
        # print(group)
    group=group[['thrpt_mp']]

    plt.plot(group.index,group['thrpt_mp'],label=group_key)

    # if(group_key=="balia"):
    # group.plot(color="red")

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)
            


    tcp_list.append(group_key)
    tcp_list_pd.append(group)


    # group.plot(color="red")
    # from matplotlib.pyplot import figure

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)

title="Goodput vs loss percentage in network b"
plt.title("Goodput vs loss percentage in network b")
plt.legend()
plt.savefig("./iperf3_tests/"+title+"-"+"Graphs.png", dpi=100,facecolor='white', transparent=False,bbox_inches='tight')
plt.show()

# %%
import pandas as pd

import numpy as np

df=pd.read_csv("./losspercentagedata/results-triale.txt", names=["experiment_number","congestion_control","loss_percentage","thrpt_mp1","thrpt_mp2","unit","latency_name","latency"])

# %%
df
# Out:
#      experiment_number congestion_control  loss_percentage  thrpt_mp1  \
# 0                    1               reno            0.001      22.20
# 1                    1                pcc            0.001      28.60
# 2                    1              balia            0.001      13.40
# 3                    1                bbr            0.001      81.60
# 4                    1                lia            0.001      13.10
# ..                 ...                ...              ...        ...
# 171                  2                bbr           10.000      19.20
# 172                  2                lia           10.000       0.54
# 173                  2               olia           10.000       0.44
# 174                  2             wvegas           10.000       0.49
# 175                  2           pcc_loss           10.000       2.92
#
#      thrpt_mp2       unit latency_name   latency
# 0        22.20  Mbits/sec      latency   60.4274
# 1        30.40  Mbits/sec      latency   66.6533
# 2        13.10  Mbits/sec      latency   60.8213
# 3        14.80  Mbits/sec      latency   78.0565
# 4        13.20  Mbits/sec      latency   60.9178
# ..         ...        ...          ...       ...
# 171      15.10  Mbits/sec      latency  112.1820
# 172       0.51  Mbits/sec      latency   70.7869
# 173       0.46  Mbits/sec      latency   64.5020
# 174       0.39  Mbits/sec      latency   68.0355
# 175       3.67  Mbits/sec      latency   61.6254
#
# [176 rows x 8 columns]

# %%
train_df=df.copy()
train_df.set_index(df['loss_percentage'])

tcp_group=train_df.groupby(df['congestion_control'])

import matplotlib.pyplot as plt
import numpy as np

from matplotlib.pyplot import figure


tcp_list=[]
tcp_list_pd=[]


for group_key, group_value in tcp_group:
    group = tcp_group.get_group(group_key)
    group=group.set_index(group['loss_percentage'])
    group=group.groupby(group.index).mean()
    group=group[['latency']]

    plt.plot(group.index,group['latency'],label=group_key)
    

    # if(group_key=="balia"):
    # group.plot(color="red")

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)
            


    tcp_list.append(group_key)
    tcp_list_pd.append(group)


    # group.plot(color="red")
    # from matplotlib.pyplot import figure

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)

title="latency vs loss percentage in network c"
plt.title("latency vs loss percentage in network c")
plt.legend()
plt.savefig("./iperf3_tests/"+title+"-"+"Graphs.png", dpi=100,facecolor='white', transparent=False,bbox_inches='tight')
plt.show()



train_df=df.copy()
train_df.set_index(df['loss_percentage'])

tcp_group=train_df.groupby(df['congestion_control'])

train_df_temp=train_df.loc[train_df['congestion_control']=="reno"]

train_df

import matplotlib.pyplot as plt
import numpy as np

from matplotlib.pyplot import figure


tcp_list=[]
tcp_list_pd=[]


for group_key, group_value in tcp_group:
    group = tcp_group.get_group(group_key)
    group=group.set_index(group['loss_percentage'])
    group=group.groupby(group.index).mean()
    
    group['thrpt_mp']=group['thrpt_mp1']
        # print(group)
    group=group[['thrpt_mp']]

    plt.plot(group.index,group['thrpt_mp'],label=group_key)

    # if(group_key=="balia"):
    # group.plot(color="red")

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)
            


    tcp_list.append(group_key)
    tcp_list_pd.append(group)


    # group.plot(color="red")
    # from matplotlib.pyplot import figure

    # fig = plt.gcf()
    # title=group_key
    # plt.title(title)
    # fig.set_size_inches(18.5, 10.5)
    # fig.savefig("Graphs.png", dpi=100,facecolor='white', transparent=False)

title="Goodput vs loss percentage in network c"
plt.title("Goodput vs loss percentage in network c")
plt.legend()
plt.savefig("./iperf3_tests/"+title+"-"+"Graphs.png", dpi=100,facecolor='white', transparent=False,bbox_inches='tight')
plt.show()
